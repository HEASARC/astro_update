# %% [markdown]
# # Imports

# %%
# %pylab inline
from bs4 import BeautifulSoup
import urllib2
import subprocess
import requests
import re
import json
import pandas as pd
import pprint
from utils import html_to_pandas
import astroupdate as ad
import datetime
from dateutil.parser import parse
import jinja2
from flask import render_template, render_template_string
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # How to get the latest version id for a given software package from astro-update</h3>

# %%
response = urllib2.urlopen('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/')
html=response.read()

# %%
soup=BeautifulSoup(''.join(html))

# %%
table=soup.findAll('table')
soft_table=table[1] # there are 3 tables on the page, the software version table is the 2nd table

# %%
rows = soft_table.findAll('tr')
i=0
name=[]
for row in rows[1:]:
    cols = row.findAll('td')
    i=i+1
    n   =''.join(cols[0].find(text=True))
    name.append(n)
    rep    =''.join(cols[1].find(text=True))
    vers   =''.join(cols[2].find(text=True))
    moddate=''.join(cols[3].find(text=True))
    print "%i %s was last updated by %s to version %s on %s" % (i,n, rep, vers, moddate)
#    progname=''.join(td.find(text=True))
#    print progname

# %%
if 'fv' in name:
    print "CPL in name"

# %% [markdown]
# ## Python Modules

# %%
import sys

def astroupdate_dict2(url="http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/"):
    from bs4 import BeautifulSoup
    import urllib2
    response = urllib2.urlopen('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/')
    html=response.read()
    soup=BeautifulSoup(''.join(html),'lxml')
    table=soup.findAll('table')
    soft_table=table[1] # there are 3 tables on the page, the software version table is the 2nd table
    rows = soft_table.findAll('tr')
    au_dict=dict()
    for row in rows[1:]:
        cols = row.findAll('td')
        n   =''.join(cols[0].find(text=True))
        r   =''.join(cols[1].find(text=True))
        v   =''.join(cols[2].find(text=True))
        m   =''.join(cols[3].find(text=True))
        au_dict[n]=(v.strip(),m.strip(),r.strip())
    return au_dict

def astroupdate_dict(url="http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/"):
    from bs4 import BeautifulSoup
    import urllib2
    response = urllib2.urlopen('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/')
    html=response.read()
    soup=BeautifulSoup(''.join(html),'lxml')
    table=soup.findAll('table')
    soft_table=table[1] # there are 3 tables on the page, the software version table is the 2nd table
    rows = soft_table.findAll('tr')
    au_dict=dict()
    for row in rows[1:]:
        cols = row.findAll('td')
        n   =''.join(cols[0].find(text=True))
        r   =''.join(cols[1].find(text=True))
        v   =''.join(cols[2].find(text=True))
        m   =''.join(cols[3].find(text=True))
        homepage = cols[0].findAll('a')[0]['href']
        download = cols[2].findAll('a')[0]['href']
        au_dict[str(n).lower().strip()]={'Version':str(v).strip(),
                                         'Date':str(m).strip(),'Author':str(r).strip(), 
                                         'HomePage':homepage, 'Download':download}
    return au_dict
        
        
def astroupdate(software):
    aud=astroupdate_dict()
    softkey=software.strip().lower()
    try:
        aud[softkey]
    except KeyError, errmsg:
        print "{0} ({1}) not monitored by Astro-Update".format(software, softkey)
        print "Valid entries are:"
        print ' '.join(aud.keys())
        ver, date, author = '','',''
        return ver, date, author
    print "{0} was last updated to version {1} on {2} by {3}".format(software, 
                                                                     aud[softkey]['Version'], 
                                                                     aud[softkey]['Date'], 
                                                                     aud[softkey]['Author'])
    ver = str(aud[softkey]['Version']) 
    date = str(aud[softkey]['Date'])
    author = str(aud[softkey]['Author'])


    return ver, date, author   


        
def auto_update(software):
    """
    for the specified software, notify the user if their installed version is up-to-date; if not,
    give the user the option of downloading the latest version (by taking the user to the
    software download page in their web browser)

    :param software: name of software to check
    :return:
    """
    ad = astroupdate_dict()
    software = software.strip().lower()
    try:
        current_vers = ad[software]['Version']
    except:
        print "{0} not found in Astro-Update Database; returning".format(software)
        return
    updateurl = ad[software]["URL"]

    """
    Compare installed version of software to most recent version
    """

    if software=="heasoft":
        headasdir = os.getenv('HEADAS')
        if not headasdir:
            print "HEASoft not configured (environment variable $HEADAS is not defined); stopping"
            return
        try:
            fver_installed = subprocess.check_output(['fversion'])
        except:
            print "fversion failed; is HEASoft installed?"
            sys.exit()
        vers=fver_installed.strip("\n").split('_V')
        vers=vers[1].rstrip()
        print "Latest version of  HEASoft = %s; You currently have HEASoft version %s" % (current_vers, vers)
        if current_vers.strip()<> vers.strip():
            ans=''
            ans=raw_input("Would you like to update (Y/n)? ")
            if ans.strip()=='' or ans[0].lower()=='y':
                print "Opening HEASoft download page in your web browser"
                #webbrowser.open('http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/download.html')
                webbrowser.open(updateurl)

    if software=='sae':
        fermidir = os.getenv('FERMI_DIR')
        if not fermidir:
            print "SAE not configured (environment variable $FERMI_DIR is not defined); stopping"
            return
        STools = glob.glob(fermidir+'/../../ScienceTools*') # Find Science Tools directory
        #print STools
        foundversion = False
        if not STools:
            print "Problem finding {0}; Is SAE installed?".format(fermidir+'/../..')
            return
        vers = STools[0].split('Tools-')[1].split('-fssc')[0].strip()
        #print SToolsver
        print "The current version of the Science Analysis Environment for Fermi is {0}; you have version {1}".format(current_vers.strip(), vers.strip())
        if current_vers.strip()<>vers.strip():
            ans=raw_input("Would you like to update (Y/n)? ")
            if ans.strip()=='' or ans[0].lower()=='y':
                print "Opening Fermi SAE download page in your web browser"
                #webbrowser.open('http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/')
                webbrowser.open(updateurl)

    if software =='xspec':
        headasdir = os.getenv('HEADAS')
        foundversion = False
        if not headasdir:
            print "XSPEC not configured (environment variable $HEADAS is not defined); stopping"
            return
        """
        Get installed primary version number from locally installed manual.html; this is defined as a constant in
        the file $HEADAS/../Xspec/src/XSUtil/Utils/XSutility.cxx in a line like this: static const string version = "12.9.0b";
        """
        xsutil=headasdir+'/../Xspec/src/XSUtil/Utils/XSutility.cxx'
        f=open(xsutil,'r')
        for line in f.readlines():
            #print line
            if 'version =' in line:
                #print line
                vers = line.split('=')[1].strip().split('"')[1]
                #print 'Vers = {0}'.format(vers.strip())
                foundversion=True
                break
        f.close()
        if not foundversion:
            print "Could not find local XSpec version; stopping"
            return
        print "The current version of XSpec is {0}; you have version {1}".format(current_vers.strip(), vers.strip())
        if current_vers.strip()<>vers.strip():
            ans=raw_input("Would you like to update (Y/n)? ")
            if ans.strip()=='' or ans[0].lower()=='y':
                print "Opening the XSpec download page in your web browser"
                #webbrowser.open('http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/')
                webbrowser.open(updateurl)

    if software == 'ciao':
        ascds = os.getenv('ASCDS_INSTALL')
        if not ascds:
            print "CIAO not configured (environment variable $ASCDS_INSTALL is not defined); stopping"
            return
        os.system(ascds+'/contrib/bin/check_ciao_version')


    if software == 'sas':
        sasdir = os.getenv('SAS_DIR')
        if not sasdir:
            print "SAS not configured (environment variable $SAS_DIR is not defined); stopping"
            return
        vers = sasdir.split('sas_')[1].split('/')[0]
        print "The current version of SAS is {0}; you have version {1}".format(current_vers.strip(), vers.strip())
        if current_vers.strip() <> vers.strip():
            ans = raw_input("Would you like to update (Y/n)? ")
            if ans.strip() == '' or ans[0].lower() == 'y':
                print "Opening SAS download page in your web browser"
                # webbrowser.open('http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/')
                webbrowser.open(updateurl)

    return

# %%
aud = astroupdate_dict()
aud['saoimage ds9']

# %%
software = 'HEASOFT'
ver, date, org = astroupdate(software)

# %%
# aud = astroupdate_dict()
key ='xxx'
astroupdate('xxx')

# %%
software='fv'
astroupdate(software)

# %% [markdown]
# # Determining the current version of a Specified Software Package
#
# For a specified software package, we want:
#     * to read the web page which has the version info
#     * extract the version info from the web page
#     * and (eventually) compare this version to the one in astro-update

# %% [markdown]
# ## Let's Try SPEX

# %%
#
# Take SPEX as an example
# idea is to find some text on the page which signals the version 
#  (something like "Current Version is ")
# locate that text on the page then extract the version
# this may have to be done uniquely for each software package
# but let's try to find the text "Version" initially
#

spex_version_page = 'https://www.sron.nl/astrophysics-spex/download'
#spex_version_id = 'version' # text on the page which indicates the version
spex_version_pattern = r'\d+.\d+.\d+' # the pattern for the version numbering scheme
pat = re.compile(spex_version_pattern)

req = requests.get(spex_version_page)
ver = pat.search(req.text)

try:
    print "The Current SPEX version is {0}".format(ver.group(0))
except:
    print "couldn't find current version of SPEX at"
    print spex_version_page
    
req.close()

# %%
ver, date, org = astroupdate('spex')

# %% [markdown]
# ## Fermi SAE

# %%
version_page = 'http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/'
#spex_version_id = 'version' # text on the page which indicates the version
version_pattern = r'v\d+r\d+p\d+' # v10r0p5 for example
pat = re.compile(version_pattern)

req = requests.get(version_page)
ver = pat.search(req.text)

try:
    print "The Current SAE version is {0}".format(ver.group(0))
except:
    print "couldn't find current version of SPEX at"
    print spex_version_page
    
req.close()

# %%
aud = astroupdate_dict()
version_pattern = {}
for k in aud.keys():
    print k, aud[k]['Version']
    pat = raw_input('Specify regular expression for version > ')
    version_pattern[k] = pat

# %% [raw]
# json.dump(version_pattern, open('resources/astro_update_version_patterns.txt','w'))

# %% [markdown]
# ## General method of Finding current version of software

# %%
#
# here's how to find the current version of the HEASoft.  Looks like we need a search key (like 
# 'Current version' for the HEASoft) or to better define the search regular expression
#
spattern = json.load(open('resources/astro_update_version_patterns.txt'))
pat = re.compile(spattern['heasoft'])

aud = astroupdate_dict()
req = requests.get(aud['heasoft']['Download'])

skey = 'Current version'
ind = req.text.index(skey)

req.text[ind:ind+100]
ver = pat.search(req.text[ind:ind+100])
print "Current version of the HEASoft is {0}".format(ver.group(0))

# %%
#
# a more robust search - using xspec as an example
#
#
# this should do it - we need to add a "version_marker" phrase for each software package
# 

spattern = json.load(open('resources/astro_update_version_patterns.txt'))

aud['xspec']
aud['xspec']['version_marker'] = 'latest update'

req = requests.get(aud['xspec']['Download'])

soup = BeautifulSoup(req.text)
# note - use soup.text to get find the version_marker to avoid embedded html
ind = soup.text.index(aud['xspec']['version_marker']) 
spattern['xspec'] = '\d+.\\d+.\\d+[a-z]'
req.close()
pat = re.compile(spattern['xspec']) 
pat.search(soup.text[ind:]).group() # only search the string after the version_marker has been found

# %% [raw]
# #
# # ok lets add a version_marker key + value to the spattern dictionary
# #
# spattern = json.load(open('resources/astro_update_version_patterns.txt'))
#
# sinfo = {}
# for k in spattern.keys():
#     print k
#     print aud[k]['Download']
#     vers_marker = raw_input('Specify text of version marker > ')
#     sinfo[k]= {'version_marker':vers_marker, 'pattern':spattern[k]}
#
# json.dump(sinfo, open('resources/astro_update_sinfo.txt','w'))

# %%
sinfo = json.load(open('resources/astro_update_sinfo.txt'))

sinfo.keys()

keys = sinfo.keys()

for k in keys:
    print k
    pat = re.compile(sinfo[k]['pattern'])

    aud = astroupdate_dict()
    req = requests.get(aud[k]['Download'])

    skey = sinfo[k]['version_marker']
    skip = False
    try: 
        ind = req.text.index(skey)
    except: 
        print "{0} not found on {1}".format(skey, aud[k]['Download'])
        skip = True
    
    if not skip:
        req.text[ind:]
        ver = pat.search(req.text[ind:ind+100])
        req.close()
        try:
            print "Current version of the {1} is {0}; expected {2}".format(ver.group(0), k, aud[k]['Version'])
        except:
            print "Version for {0} not found on {1}".format(k, aud[k]['Download'])

# %% [markdown]
# # How to find the latest version for a CALDB</h2>
#
# we define a caldb python dictionary as follows:
#
# caldb={'ASCA':{'GIS':20060711,'SIS':19991111,'XRT':19991111,'MIS':19940114}, 'BEPPOSAX':{'HGSPC':1999, 'LECS':1999, 'MECS':1999, 'PDS':1999, 'WFC':1999} ...}
#
# this dictionary should be defined by parsing the "supported missions" webpage
# http://heasarc.gsfc.nasa.gov/docs/heasarc/caldb/caldb_supported_missions.html

# %%
def caldb_dict(url="http://heasarc.gsfc.nasa.gov/docs/heasarc/caldb/caldb_supported_missions.html"):
    """
    Parse the caldb supported missions web page and convert to a python library
    """
    from bs4 import BeautifulSoup
    import urllib2
    response = urllib2.urlopen(url)
    html=response.read()
    soup=BeautifulSoup(''.join(html))
    table=soup.findAll('table')
    hcal_table=table[1] # there are 3 tables on the page, the caldb version table is the 2nd table
    rows = hcal_table.findAll('tr')
    #a= ''.join(cols.find(text=True)).strip()
    #print a
    caldb_dict=dict()
    """
    Read first row - contains the first mission
       if first cell in row is not empty: mission name=mis
    """
    cols = rows[0].findAll('td')
    mis =str(cols[0].find(text=True)).strip().lower()
    #print "Found %s" % mis
    """
    Read next row
       check that first cell in row is empty: 
         if cell empty, then add to instrument dictionary
            inst_dict[cell[1]]=cell[2] (i.e. something like inst_dict={'XIS':'20140101'}) 
                 where cell[1] is the instrument name (XIS) and cell[2] is the version date 
          if cell is not empty: found new mission
               so store instr_dict in caldb_dict for previous mission: CALDB_DICT[MIS]=inst_dict
               set mis = new mission
               clear inst_dict
               repeat
    """
    inst_dict=dict()
    for row in rows[1:]: # omit first row (i.e. row 0)
        cols = row.findAll('td')
        #print cols[0]
        a=cols[0].find(text=True)
        #print a
        if len(a.strip()) == 0: # no entry in mission cell, so these are instruments
            inst= str(cols[1].find(text=True)).strip().lower()
            vers= str(cols[2].find(text=True)).strip()
            #print mis, inst, vers
            try:
                inst_dict[inst]=caldate2vers(vers)
            except:
                inst_dict[inst]=vers
        else: # save instruments & version in mission dictionary
            #print inst_dict
            #print "current mission is %s" % mis
            caldb_dict[mis]=inst_dict
            #print caldb_dict
            inst_dict=dict()
            mis=str(a.strip()).lower()
            #print "Found new mission %s " % mis
    return caldb_dict

def caldate2vers(update_date):
    """
    converts latest update dates (a string in mmm 00, yyyy format) to yyyymmdd format
    """
    month=({'Apr':'04','Aug':'08','Dec':'12','Feb':'02','Jan':'01','Jul':'07','Jun':'06','Mar':'03','May':'05','Nov':'11',
          'Oct':'10','Sep':'09'})
    a=update_date.split(',')
    yyyy=a[1].strip()
    b=a[0].split()
    mon=b[0]
    day=b[1]
    return yyyy+month[mon]+day
    
def current_caldb_vers(mis, inst):
    import ftplib
    caldir="caldb/data/"+mis.lower().strip()+"/"+inst.lower().strip()
    ftp = ftplib.FTP("heasarc.gsfc.nasa.gov")
    ftp.login("anonymous", "")
    ftpmess=ftp.cwd(caldir)
    list=[]
    ftp.dir('caldb.indx', list.append)
    ftp.close()
    vers=list[0].split()[-1].split('/')[1].split('indx')[-1] #[-1] is the last element
    return vers

# %%
caldict=caldb_dict()

# %%
mis='rxte'
inst='pca'
print caldict[mis][inst]
cur_vers=current_caldb_vers(mis, inst)
print cur_vers
if caldict['nustar']['fpm']==cur_vers:
    print "You're Current!"
else:
    print "Not current :-("

# %%
caldict['rxte']

# %%
a=caldict['ASCA']['GIS'].split(',')
yyyy=a[1].strip()
yyyy
a[0]
a[0].split()
c='1999'+'11'+'11'
c

print caldict['ASCA']['GIS']
print caldate2vers('Nov 11, 1999')

# %%
cal_dict

# %%
caldict['ASCA']

# %%
a={'b':'c',2:5}
a
a.clear()
a

# %%
from bs4 import BeautifulSoup
import urllib2
url="http://heasarc.gsfc.nasa.gov/docs/heasarc/caldb/caldb_supported_missions.html"
response = urllib2.urlopen(url)
html=response.read()
soup = BeautifulSoup(html)
table=soup.findAll('table')
hcal_table=table[1]# there are 3 tables on the page, the software version table is the 2nd table
rows = hcal_table.findAll('tr')
cols = rows[3].findAll('td')
mis =str(cols[0].find(text=True))

# %%
import calendar
enumerate(calendar.month_abbr)
dict((v,k) for k,v in enumerate(calendar.month_abbr))

# %%
mon['Sep']

# %%
import ftplib
ftp = ftplib.FTP("heasarc.gsfc.nasa.gov")
ftp.login("anonymous", "")
ftpmess=ftp.cwd("caldb/data/nustar/fpm")
list=[]
ftp.dir('caldb.indx', list.append)
ftp.close()
list

# %%
a=list[0].split()

# %%
a[-1]

# %%
vers=list[0].split()[-1].split('/')[1].split('indx')[-1]

# %%
vers

# %% [markdown]
# a is {{13.5/2.0}}

# %% [markdown]
# # JSON files for each software package
#
# Let's create a json file for each software package, for example
#
# ```/software/github/heasarc/astro-update/astroupdate_resources/ds9_au.json```
#
# to hold information needed to determine the version number of the software package
# and also to store the link information
#
# Note: this could  probably work but it requires that each software page have it's own regular expression, and it's difficult to construct regular expressions for each software package that will be general enough ("7.5" vs "7.5.1" for example)

# %% [markdown]
# ## this create a dataframe from the json dictionary for a specified software package.
#
# In printciple this method could be used to create the html data for the astroupdate page

# %%
# get defs for ds9 and POA
jds9 = "/software/github/heasarc/astro_update/definitions/ds9_au.json"
d = json.load(open(jds9, mode='r'))
d['saoimage ds9'].keys()
testdf = pd.DataFrame.from_dict(data=d, orient='index')
jpoa = "/software/github/heasarc/astro_update/definitions/poa_au.json"
dpoa = json.load(open(jpoa, mode='r'))

# %%
jaud = "/software/github/heasarc/astro_update/definitions/astroupdate_defs.json"
daud = json.load(open(jaud, mode='r'))
testdf  = pd.DataFrame.from_dict(daud, orient='index')
testdf

# %%
testdf.loc['poa'].version_url
req = requests.get(testdf.loc['poa'].version_url)
alesoup = BeautifulSoup(req.text,'lxml')
testdf.loc['poa'].pattern_marker
ind = alesoup.text.lower().find('the most recent version')
re.compile(testdf.loc['poa'].pattern).search(alesoup.text[ind:ind+100]).group()

# %%
try:
    testdf.loc['PINT of ALE'].version_url
except KeyError, errmsg:
    print "{0}".format(errmsg)
    print('Available software keys')
    for x in testdf.index:
        print x,

# %%
testdf.keys()

# %%
req = requests.get(d['saoimage ds9']['version_url'])

# %%
ind = req.text.index(d['saoimage ds9']['pattern_marker'])
pat=re.compile(d['saoimage ds9']['pattern'])

# %%
m = pat.search(req.text,ind, ind+100)

# %%
req.text[ind:ind+200]

# %%
txt = u'SAOImage DS9 Version 7.5.1</span>'

# %%
pat = re.compile("\\d\.\\d?\.?\\d?")
m = pat.search(txt)
m.group()

# %% [markdown]
# # A Crude Alternative
#
# would be to have a script that would read the astro_update dictionary, display the current version, then display the software web page showing the current version of the software package; the user could then enter a yes or no if the astro-update info for that package needed to be updated

# %%
import webbrowser

# %%
for soft in aud.keys():
    print "Astro-Update Version of {1} = {0}".format(aud[soft]['Version'], soft)
    print "Display Version page for {0}".format(soft)
    webbrowser.open(aud[soft]['HomePage'])
    ans = raw_input('Enter Version (<0 to ignore) > ')

# %%
aud['heasoft']

# %% [markdown]
# # Using Pandas to parse astro-update html table
#
# Pandas is useful to sort the table by version date - but pandas "read_html" function seems to strip out the links from the columns and just return the column text.  How can we keep the links?
#
# What I'd like to do:
# * get the html data with requests.get()
# * parse the html with BeautifulSoup and get the table of interest
# * either add a row (or rows) or update  existing row/rows
# * sort the table by time (descending)
# * create an updated astroupdate.html page with the updated table

# %%
# get html with requests
req = requests.get('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update')
# create soup and extract table
soup = BeautifulSoup(req.text)
autab = soup('table')[1]
# update row or add new row
# 
# then create dataframe
audf = pd.read_html(str(autab))[0]
# sort dataframe by "Last Update"
auddf['Last Update'] = pd.to_datetime(auddf['Last Update'])
auddf.head()
auddfsort = auddf.sort_values(by = 'Last Update', ascending=False)
nsoup = BeautifulSoup(auddf.to_html())
nsoup('tr')[2]('td')

# %%
test= list(autab('tr')[1]('td'))
reshape(test,(1,4))
dftest = pd.DataFrame(data=reshape(test,(1,4)), columns = ['Name','resp','version','update'])
print(dftest['Name'])

# %%
a=str(dftest['Name'][0])
s = BeautifulSoup(a)
s

# %%
auddf = aud[1]
auddf.head()

# %% [markdown]
# ## sorting the dataframe by time

# %%
auddf['Last Update'] = pd.to_datetime(auddf['Last Update'])
auddf.sort_values(by='Last Update')

# %% [markdown]
# # Using BeautifulSoup to parse astro-update html table
#
# let's create astro-update definition files from the current (2017-01-31) astro-update table

# %%
req = requests.get('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/')

# %%
ausoup = BeautifulSoup(req.text,'lxml')

# %%
tab = ausoup.findAll('table')

# %%
rows = tab[1].find_all('tr')

# %%
for r in rows[1:]: # skip 1st (header) row
    col = r.findAll('td')
    name = str(col[0].text.split(':')[0].strip().lower())
    try:
        desc = str(col[0].text.split(':')[1]).strip()
    except IndexError:
        print "Could not get description for {0}".format(name)
        desc = name
    homepage = str(col[0].a.get('href'))
    auth = str(col[1].text)
    ver = str(col[2].text)
    download = str(col[2].a.get('href'))
    updated = str(col[3].text)
    # note - json needs strings to have double, not single, quotes
    audict = {"{0}".format(name):{"pattern":"\\d+\\.{0,1}\\d+",
                                    "pattern_description":"one or more digits followed by zeror or 1 period followed by one or more digits",
                                    "pattern_marker":"version",
                                    "home_url":"{0}".format(homepage),
                                    "download_url":"{0}".format(download),
                                    "version_url":"{0}".format(download),
                                    "description":"{0}".format(desc),
                                    "author":"{0}".format(auth),
                                    "author_page":"{0}".format(homepage)}}
    fdir = '/software/github/heasarc/astro_update/definitions/TEST'
    fname = "{0}/{1}_au.json".format(fdir,name)
    try:
        with open(fname, mode='w') as fout:
            json.dump(audict, fout, indent=4)
    except IOError, errmsg:
        print errmsg

# %%
print audict

# %% [markdown]
# ## Create an astroupdate row

# %%
req = requests.get('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/')
ausoup = BeautifulSoup(req.text,'lxml')
tab = ausoup.findAll('table')
#cols = tab[1].find_all('tr')[3].find_all('td')
cols = tab[1]('tr')[3]('td')
cols[0]

# %%
aud = json.load(open('definitions/TEST/pyraf_au.json'))

# %%
cols[0].a.next_sibling

# %% [markdown]
# # Retaining links in an html table using pd.read_html
#
# pd.read_html only returns the text from an html table without the links; you need to do some work to maintain the links
#
# see http://stackoverflow.com/questions/31771619/html-table-to-pandas-table-info-inside-html-tags
#
# 20170202: the util.html_to_pandas function solves this problem!

# %%
req = requests.get('http://heasarc.gsfc.nasa.gov/docs/heasarc/astro-update/')
audtable = BeautifulSoup(req.text,'lxml')('table')[1]

# %%
auddf[auddf.columns[0]][0]

# %%
# see http://stackoverflow.com/questions/26277757/pandas-to-html-truncates-string-contents
pd.set_option('display.max_colwidth', -1)
auddf['sortdate'] = pd.to_datetime(auddf['Last Update'])
auddf.sort_values(by="sortdate", ascending=True, inplace=True)
auddf[auddf.columns[0]].iloc[0]

soup = BeautifulSoup(auddf.to_html(escape=False),'lxml')('table')[0]
print(soup.prettify())

# %%
auddf = ad.read_au_defs()

# %%
auddf.loc['poa'].pattern

# %%
auddf.loc['poa'].name

# %%
auddf.loc[auddf.index[0]]

# %% [markdown]
# # Update and output the astro-update defs database

# %%
adj  = json.load(open('definitions/astroupdate_defs.json','r'))

# %%
adj['browse']['ad_version'] = '0.9'

# %%
print json.dumps(adj,indent=4) # this prints a nicely formatted json dictionary

# %% [markdown]
# # output the AU dataframe as a json file
#
# to be done after updating the software version and release date, for example

# %%
# Can we pretty print the pandas dataframe as a json file?

apd = ad.read_au_defs()
apd.loc['cfitsio'].ad_version = '1.0'
apdj = apd.to_json(orient='index')
p=json.loads(apdj)
print json.dumps(p,indent=4) # this prints a nicely formatted json dictionary

# %% [markdown]
# ## Sort the dataframe by time
#
# see http://stackoverflow.com/questions/28161356/sort-pandas-dataframe-by-date

# %%
#
# Example
#
pdf = pd.DataFrame( {'Symbol':['A','F','C'] ,
    'Date':['12/14/16','12/15/16','08/21/14']})
pdf.Date = pd.to_datetime(pdf.Date)
pdf.sort_values(by='Date', ascending=False)
# Out:
#         Date Symbol
# 1 2016-12-15  F
# 0 2016-12-14  A
# 2 2014-08-21  C

# %%
apd = ad.read_au_defs()
aud = ad.read_au_defs()

# %%
apd.ad_release_date = pd.to_datetime(apd.ad_release_date, errors="coerce")
apd.sort_values(by='ad_release_date', ascending=False, inplace=True)
apd[['ad_release_date']]
# Out:
#                     ad_release_date
# xamin               2017-02-14
# tempo2              2017-02-14
# casa                2017-02-08
# vltpipe             2017-01-27
# apt                 2017-01-26
# heasoft             2017-01-18
# aladin              2017-01-17
# xspec               2017-01-17
# visit               2017-01-16
# pimms               2017-01-16
# pyraf               2017-01-16
# sas                 2017-01-16
# wcslib              2017-01-15
# xstar               2017-01-10
# ciao                2017-01-05
# iris                2017-01-04
# aips                2016-12-31
# montage             2016-12-21
# marx                2016-12-16
# sherpa              2016-12-16
# ds9                 2016-12-15
# skyview             2016-12-13
# gsl                 2016-12-09
# atomdb              2016-12-08
# idlaul              2016-12-08
# cfitsio             2016-12-02
# xsa                 2016-11-30
# tara                2016-09-26
# acis_extract        2016-09-22
# isis                2016-09-12
# ...                        ...
# splash              2015-10-22
# chianti             2015-09-16
# fv                  2015-09-15
# sae                 2015-06-24
# window2stars        2015-04-16
# amuse               2014-09-17
# specview            2014-06-02
# stsci_python        2014-04-16
# camb                2014-04-16
# stsdas              2014-03-16
# starview            2013-03-07
# mopex               2012-10-10
# astrogrid           2012-08-15
# tlusty              2012-07-02
# iraf                2012-03-22
# ximage              2010-03-16
# grace               2008-05-20
# browse              2007-10-09
# profit              2007-08-07
# synspec             2005-10-05
# eclipse             2005-09-23
# xronos              2004-05-07
# exsas               2003-12-10
# sextractor          2002-04-09
# pros                1998-08-25
# browse_extract_wget 1996-10-10
# browse_extract      1996-10-10
# poa                 NaT
# starlink            NaT
# webhera             NaT
#
# [69 rows x 1 columns]

# %% [markdown]
# # Rendering the web page as a static html file
#
# see https://realpython.com/blog/python/primer-on-jinja-templating/
#
# and http://kagerato.net/articles/software/libraries/jinja-quickstart.html

# %%
templateLoader = jinja2.FileSystemLoader( searchpath="/software/github/heasarc/astro_update/templates" )
templateEnv = jinja2.Environment( loader=templateLoader )
template = templateEnv.get_template('test_table.html')

# %%
audef = ad.read_au_defs()
# convert release date to a datetime object...
audef.ad_release_date = pd.to_datetime(audef.ad_release_date, errors="coerce")
# ... then sort by release_date
audef.sort_values(by='ad_release_date', ascending=False, inplace=True)
# strip out the rows without a defined release_date
audef_for_web = audef[audef.ad_release_date.notnull()]

# %%
output_text = template.render(audef= audef_for_web)

# %%
f = open('/software/github/heasarc/astro_update/html/astroupdate_test.html', mode='w')

# %%
f.write(output_text)

# %%
f.close()

# %%
aud = ad.read_au_defs()

# %%
aud.loc['xamin']['name']
# Out:
# u'XAMIN'

# %%
aud
# Out:
#                                        release_pattern  \
# acis_extract         \d{2}\-\D{3}\-\d{4}
# aips                 \d{2}-\D{3}-\d{4}
# aladin               \d{1,2}/\d{1,2}/\d{4}
# amuse                \d{2}/\d{2}/\d{2}
# apt                  [a-zA-Z]+\s{1}\d{1,2},\s{1}\d{4}
# astrogrid            \d{2}-\D{3}-\d{4}
# atomdb               [a-z,A-Z]+\s\d{1}\D{2}\s{1}\d{4}
# browse               [a-z,A-Z]+\s\d{1},\s{1}\d{4}
# browse_extract       \d{4}-\d{2}-\d{2}
# browse_extract_wget  \d{4}-\d{2}-\d{2}
# camb                 [a-z,A-Z]+\s{1}\d{4}
# casa                 [a-z,A-Z]+\s\d{1,2},\s\d{4}
# ccfits               \d{2}-\D{3}-\d{4}
# cfitsio              \d{2}-\D{3}-\d{4}
# chianti              \D{3,4}\s\d{4}
# ciao                 \d{1,2}\s[a-z,A-Z]+\s\d{4}
# cpl                  \d{1,2}-\D{3}-\d{4}
# ds9                  \D{3}\s\d{1,2},\s\d{4}
# eclipse              \d{1,2}\s[a-z,A-Z]+\s\d{4}
# exsas                \d{4}/\d{2}/\d{2}
# fv                   \d{2}-\D{3}-\d{4}
# galprop              [a-z,A-Z]+\s\d{1,2},\s\d{4}
# gasgano              \d{2}\.\d{2}.\d{2}
# grace                \d{2}\.\d{2}.\d{4}
# gsl                  \d{1,2}\s{1}[a-z,A-Z]+\s{1}\d{4}
# heasoft              [a-z,A-Z]+\s{1}\d{1,2},\s{1}\d{4}
# idlaul               \d{2}-\D{3}-\d{4}
# iraf                 [a-z,A-Z]+\s\d{2},\s\d{4}
# iris                 \d{4}-\d{2}-\d{2}
# isis                 [a-z,A-Z]+\s\d{2},\s\d{4}
# ...                                        ...
# pyraf                \D{3}\s\d{4}
# sae                  \D{3}\s\d{2},\s\d{4}
# sas                  [a-z,A-Z]+\s\d{1,2},\s\d{4}
# scisoft              \d{2}\.\d{2}\.\d{2}
# sextractor           \d{4}-\d{2}-\d{2}
# sherpa               [a-z,A-Z]+\s\d{1,2},\s\d{4}
# simx                 [a-z,A-Z]+\s\d{1,2},\s\d{4}
# skyview              [a-z,A-Z]+\s\d{1,2},\s\d{4}
# specview             [a-z,A-Z]+\s\d{2},\s\d{4}
# spex                 [a-z,A-Z]+\s\d{4}
# splash               \d+\D{2}\s[a-z,A-Z]+\s\d{4}
# starlink             \d{4}-\d{2}-\d{2}
# starview             \d{4}-\d{2}-\d{2}
# stsci_python         [a-z,A-Z]+\s\d{4}
# stsdas               [a-z,A-Z]+\s\d{4}
# synspec              [a-z,A-Z]+\s\d{1,2},\s\d{4}
# tara                 \d{2}-\D{3}-\d{4}
# tempo2               \d{4}-\d{2}-\d{2}
# tlusty               [a-z,A-Z]+\s\d{1,2},\s\d{4}
# visit                [a-z,A-Z]+,\s\d{4}
# vltpipe              [a-z,A-Z]+\s\d{2},\s\d{4}
# wcslib               \D{3}\s\d{2}\s\d{4}
# webhera              \d+\D{2}\s[a-z,A-Z]+\s\d{4}
# window2stars         \d{2}/\d{4}
# xamin                \d{4}-\d{2}-\d{2}
# ximage               [a-z,A-Z]+\s\d{4}
# xronos               \d{2}-\D{3}-\d{4}
# xsa                  \d{2}\s[a-z,A-Z]+\s\d{4}
# xspec                \d{2}/\d{2}/\d{2}
# xstar                \d{2}-\D{3}-\d{4}
#
#                                                                                   release_description  \
# acis_extract         MM/DD/YY
# aips                 dd-mon-yyyy
# aladin               Dec 15, 2016
# amuse                MM/DD/YY
# apt                  (Full month name) (1-2 digit day of month), (4 digit year)
# astrogrid            (Full month name) (1-2 digit day of month), (4 digit year)
# atomdb               Full name of month, 1-2 digit day, 2 character for st, th, etc,  four digit year
# browse               Full name of month, 1-2 digit day, four digit year
# browse_extract       four digit year, dash, two digit month, dash, two digit day
# browse_extract_wget  four digit year, dash, two digit month, dash, two digit day
# camb                 Month name and 4 digit year
# casa                 Dec 15, 2016
# ccfits               19-Jan-2016
# cfitsio              Friday, 02-Dec-2016 17:44:23 EST
# chianti              Sept 2015
# ciao                 Sept 2015
# cpl                  26-Feb-2016
# ds9                  Dec 15, 2016
# eclipse              23 Sept 2005
# exsas                2003/12/10
# fv                   Friday, 02-Dec-2016 17:44:23 EST
# galprop              August 12, 2016
# gasgano              22.10.15
# grace                20.05.2008
# gsl                  1-2 digit day of month full month 4 digit year
# heasoft              (Full month name) (1-2 digit day of month), (4 digit year)
# idlaul               08-Dec-2016
# iraf                 March 22, 2012
# iris                  2017-01-04
# isis                 Sep 12, 2016
# ...                           ...
# pyraf                (Full month name) (1-2 digit day of month), (4 digit year)
# sae                  (Full month name) (1-2 digit day of month), (4 digit year)
# sas                  January 16, 2017
# scisoft              dd.mm.yy
# sextractor           4 digit year dash 2 digit month dash 2 digit day
# sherpa               December 16, 2016
# simx                 December 16, 2016
# skyview              December 16, 2016
# specview             June 02, 2014
# spex                 January 2016
# splash               22nd Oct 2015
# starlink             2016-11-15
# starview             2013-03-07
# stsci_python         April 2014
# stsdas               April 2014
# synspec              October 5, 2005
# tara                 26-Sep-2016
# tempo2               2016-12-05
# tlusty               October 5, 2005
# visit                January, 2017
# vltpipe              January 27, 2017
# wcslib               Jan 15 2017
# webhera              22nd Oct 2015
# window2stars         04/2015
# xamin                2016-08-08
# ximage               March 2010
# xronos                07-May-2004
# xsa                  30 November 2016
# xspec                 01/17/17
# xstar                 10-Jan-2017
#
#                                                                               description  \
# acis_extract         IDL software for analysis of Chandra/ACIS data
# aips                 Astronomical Image Processing System
# aladin               Desktop Observatory to visualize and manipulate astronomical images
# amuse                Astrophysical Multipurpose Software Environment for simulations
# apt                  Astronomers Proposal Tool
# astrogrid            Virtual Observatory Software for Astronomers
# atomdb               atomic database for X-ray plasma spectral modeling
# browse               Old-school access to the HEASARC catalogs and data
# browse_extract       command-line query of HEASARC databases
# browse_extract_wget  command-line query of HEASARC databases, uses wget
# camb                 Code for Anisotropies in the Microwave Background
# casa                 Common Astronomy Software Applications package
# ccfits               object oriented interface to cfitsio
# cfitsio              FITS file access subroutine library
# chianti              atomic database for X-ray plasma spectral modeling
# ciao                 Chandra Interactive Analysis of Observations
# cpl                  The Common Pipeline Library
# ds9                  Astronomical image display and analysis software
# eclipse              ESO C Library for an Image Processing Software Environment
# exsas                Extended X-ray Scientific Analysis System for ROSAT
# fv                   Fits File Viewer
# galprop              Galactic Cosmic Ray Propagation
# gasgano              A Data File Organiser from ESO
# grace                A 2D plotting tool
# gsl                  a numerical C/C++ mathematical library
# heasoft              Multi-Mission High Energy Analysis software
# idlaul               IDL Astronomical Users Library
# iraf                 Image Reduction and Analysis Facility
# iris                 Spectral energy distribution (SED) analysis tool
# isis                 Interactive Spectral Interpretation System
# ...                                                         ...
# pyraf                Run IRAF tasks in Python
# sae                  Science Analysis Environment for Fermi
# sas                  XMM-Newton Science Analysis Software
# scisoft              An Astronomical Software Collection from ESO
# sextractor           Astronomical Source Extractor
# sherpa               Modeling and Fitting for CIAO
# simx                 Potential Photons from Possible Satellites
# skyview              The Internet's Virtual Telescope
# specview             1-D spectral visualization and analysis of astronomical spectrograms
# spex                 SPEctral X-ray and UV modeling, analysis and fitting
# splash               visualisation tool for output from (astrophysical) simulations
# starlink             starlinksoftware collection
# starview             Setup a telescope and control from a web browser
# stsci_python         includes PyRAF,  PyFITS, Numdisplay, MultiDrizzle for HST
# stsdas               Space Telescope Science Data Analysis System
# synspec              stellar atmospheres models for stellar spectroscopic diagnostics
# tara                 Tools for ACIS Review &amp; Analysis
# tempo2               pulsar timing software
# tlusty               stellar atmospheres and accretion disks spectrum modeling
# visit                Parallel Visualization and Graphical Analysis Tool
# vltpipe              Data reduction for the most commonly used VLT/VLTI instrument modes
# wcslib               World Coordinate System software library
# webhera              On-line Analysis of HEASARC datasets
# window2stars         Graphical interface to TWIN single/binary stellar evolution code
# xamin                Next Generation archive interface for high energy astrophysics
# ximage               Image Analysis Software
# xronos               Timing Analysis Software
# xsa                  XMM-Newton Science Archive
# xspec                X-ray spectral Analysis software
# xstar                physical conditions and emission spectra of photoionized gases
#
#                                                                                             release_url  \
# acis_extract         http://www.astro.psu.edu/xray/docs/TARA/code
# aips                 http://www.aips.nrao.edu/cook.html
# aladin               http://aladin.u-strasbg.fr/java/nph-aladin.pl?frame=downloading#Beta
# amuse                http://www.amusecode.org
# apt                  http://www.stsci.edu/hst/proposing/apt
# astrogrid            http://www.astrogrid.org/
# atomdb               http://atomdb.org
# browse               http://heasarc.gsfc.nasa.gov/W3Browse/version-history.html
# browse_extract       http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract.pl
# browse_extract_wget  http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract_wget.pl
# camb                 http://lambda.gsfc.nasa.gov/toolbox/tb_camb_form.cfm
# casa                 https://casa.nrao.edu/casa_obtaining.shtml
# ccfits               http://heasarc.gsfc.nasa.gov/docs/software/fitsio/ccfits/
# cfitsio              http://heasarc.gsfc.nasa.gov/docs/software/fitsio/fitsio.html
# chianti              http://www.chianti.rl.ac.uk/
# ciao                 http://cxc.harvard.edu/ciao/download/
# cpl                  http://www.eso.org/sci/software/cpl/
# ds9                  http://ds9.si.edu/site/Download.html
# eclipse              http://www.eso.org/sci/software/eclipse/distrib/index.html
# exsas                http://www.mpe.mpg.de/xray/wave/exsas/exsas_index.php
# fv                   http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/ftools/fv/
# galprop              http://galprop.stanford.edu/
# gasgano              http://www.eso.org/sci/software/gasgano.html
# grace                http://plasma-gate.weizmann.ac.il/Grace/doc/FAQ.html
# gsl                  http://www.gnu.org/software/gsl
# heasoft              http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/release_notes.html
# idlaul               http://idlastro.gsfc.nasa.gov/news.html
# iraf                 http://iraf.noao.edu/
# iris                 http://cxc.cfa.harvard.edu/iris/latest/releasenotes/index.html
# isis                 http://space.mit.edu/CXC/isis/download.html
# ...                                                          ...
# pyraf                http://www.stsci.edu/institute/software_hardware/pyraf/current/download
# sae                  http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/
# sas                  https://www.cosmos.esa.int/web/xmm-newton/sas-news
# scisoft              http://www.eso.org/sci/software/scisoft/
# sextractor           https://sourceforge.net/projects/sextractor/files/
# sherpa               http://cxc.harvard.edu/sherpa/updates.html
# simx                 http://hea-www.cfa.harvard.edu/simx/download.html
# skyview              http://skyview.gsfc.nasa.gov/blog/
# specview             http://www.stsci.edu/institute/software_hardware/specview/stvhistory
# spex                 https://www.sron.nl/astrophysics-spex/history
# splash               http://users.monash.edu.au/~dprice/splash/index.html
# starlink             http://starlink.eao.hawaii.edu/starlink/Releases
# starview             https://sourceforge.net/projects/starview/
# stsci_python         http://www.stsci.edu/institute/software_hardware/pyraf/stsci_python
# stsdas               http://www.stsci.edu/resources/software_hardware/stsdas
# synspec              http://nova.astro.umd.edu/Synspec43/synspec-toc
# tara                 http://www.astro.psu.edu/xray/docs/TARA/code
# tempo2               https://bitbucket.org/psrsoft/tempo2/downloads
# tlusty               http://nova.astro.umd.edu/Tlusty2002/tlusty-toc.html
# visit                https://wci.llnl.gov/simulation/computer-codes/visit/new
# vltpipe              http://www.eso.org/sci/software/pipelines/
# wcslib               http://www.atnf.csiro.au/people/mcalabre/WCS/wcslib/
# webhera              http://heasarc.gsfc.nasa.gov/webHera/
# window2stars         http://www.ast.cam.ac.uk/~rgi/code/wtts/CHANGES.WTTS
# xamin                http://heasarc.gsfc.nasa.gov/xamin/
# ximage               http://heasarc.gsfc.nasa.gov/docs/xanadu/ximage/ximrelease.html
# xronos               http://heasarc.gsfc.nasa.gov/docs/xanadu/xronos/xronrelease.html
# xsa                  https://www.cosmos.esa.int/web/xmm-newton/xsa
# xspec                http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/issues/issues.html
# xstar                http://heasarc.gsfc.nasa.gov/FTP/software/plasma_codes/xstar/
#
#                                                       author  \
# acis_extract         Broos et al.
# aips                 NRAO
# aladin               CDS
# amuse                Leiden
# apt                  STScI
# astrogrid            UK VOP
# atomdb               CXC
# browse               HEASARC
# browse_extract       HEASARC
# browse_extract_wget  HEASARC
# camb                 Lewis &amp; Challinor
# casa                 NRAO
# ccfits               HEASARC
# cfitsio              HEASARC
# chianti              GMU, U. Michigan and Cambridge
# ciao                 CXC
# cpl                  ESO
# ds9                  SAO/HEASARC
# eclipse              ESO
# exsas                MPE
# fv                   HEASARC
# galprop              Stanford
# gasgano              ESO
# grace                Weizmann
# gsl                  FSF
# heasoft              HEASARC
# idlaul               ASD/GSFC
# iraf                 NOAO
# iris                 IPAC
# isis                 CXC
# ...                  ...
# pyraf                STScI
# sae                  FSSC
# sas                  XMM-SOC
# scisoft              ESO
# sextractor           Galassi and Starr
# sherpa               CXC
# simx                 CfA
# skyview              HEASARC
# specview             STSCI
# spex                 Kaastra, Mewe and Nieuwenhuijzen (1996)
# splash               D. Price/Monash
# starlink             JAC
# starview             NWACC
# stsci_python         STScI
# stsdas               STScI
# synspec              Hubeny+Lanz
# tara                 PSU
# tempo2               ATNF
# tlusty               Hubeny+Lanz
# visit                LLNL
# vltpipe              ESO
# wcslib               Mark Calabretta
# webhera              HEASARC
# window2stars         Izzard and Glebbeek
# xamin                HEASARC
# ximage               HEASARC
# xronos               HEASARC
# xsa                  XMM-SOC
# xspec                HEASARC
# xstar                Tim Kallman/HEASARC
#
#                                          pattern  \
# acis_extract         \d{4}\D{3}\d{2}
# aips                 \d{2}-\D{3}-\d{4}
# aladin               v\d\.{0,1}\d{0,4}
# amuse                \d+\.{0,1}\d+.{0,1}\d+
# apt                  \d+\.{0,1}\d+\.{0,1}\d+
# astrogrid            \d{4}-\d{4}
# atomdb               \d{1,2}\.{0,1}\d+\.\d
# browse               v\d+\.+\d+
# browse_extract       \d+\.{0,1}\d+
# browse_extract_wget  \d+\.{0,1}\d+
# camb                 [a-z,A-Z]+\s{1}\d{4}
# casa                 \d+.\d+.\d+
# ccfits               \d+\.{0,1}\d+
# cfitsio              \d+\.{0,1}\d+
# chianti              \d+\.{0,1}\d+
# ciao                 \d+\.{0,1}\d+
# cpl                  \d+\.{0,1}\d+
# ds9                  \d\.\d?\.?\d{0,2}
# eclipse              \d+\.{0,1}\d+-\d+
# exsas                \d{2}\D{3}_\D{3}
# fv                   \d+\.{0,1}\d+
# galprop              [a-z,A-Z]+\s\d{1,2},\s\d{4}
# gasgano              \d+\.{0,1}\d+
# grace                \d+\.{0,1}\d+\.{0,1}\d+
# gsl                  \d+\.+\d
# heasoft              \d+\.{0,1}\d+
# idlaul               \d{2}-\D{3}-\d{4}
# iraf                 \d+\.{0,1}\d+
# iris                 \d+\.{0,1}\d+[a-z,A-Z]+\d+
# isis                 \d+\.\d+\.\d+-\d+
# ...                                ...
# pyraf                \d+\.{0,1}\d+\.{0,1}\d+
# sae                  v\d+r\d+p\d+
# sas                  \d+\.{0,1}\d+\.{0,1}\d+
# scisoft              \d+\.{0,1}\d{0,2}
# sextractor           \d+\.+\d+\.+\d+
# sherpa               \d+\.{0,1}\d+
# simx                 \d+\.{0,1}\d+\.{0,1}\d+
# skyview              \d+\.{0,1}\d+\.{0,1}\d+
# specview             \d+\.{0,1}\d+\.{0,1}\d+
# spex                 \d+\.{0,1}\d+\.{0,1}\d+
# splash               \d+\.{0,1}\d+\.{0,1}\d+
# starlink             \d{4}\D{1}
# starview             \d+\.{1}\d+[a-z,A-Z]+
# stsci_python         \d+\.{0,1}\d+\.{0,1}\d+
# stsdas               \d+\.{0,1}\d+
# synspec              \d+\.{0,1}\d+
# tara                 \d{4}\D{3}\d{2}
# tempo2               \d{4}\.\d+\.\d+
# tlusty               \d+\.{0,1}\d+
# visit                \d+\.{0,1}\d+\.{0,1}\d+
# vltpipe              \d+\.{0,1}\d+\.{0,1}\d+
# wcslib               \d+\.{0,1}\d+
# webhera              \d+\.{0,1}\d+
# window2stars         \d+\.{0,1}\d+
# xamin                \d+\.{0,1}\d+\.{0,1}\d+/\d+
# ximage               \d+\.{0,1}\d+\.{0,1}\d+
# xronos               \d+\.{0,1}\d+
# xsa                  \d+\.{0,1}\d+
# xspec                \d+\.{0,1}\d+.{0,1}\d+
# xstar                \d+
#
#                                    release_marker       ad_version  \
# acis_extract                                       2016sep22
# aips                 VERSION FOR                   31-DEC-2016
# aladin                                             v9.504
# amuse                release date:                 10.0
# apt                   was released on              25.0.3
# astrogrid            last updated:                 2001-2010
# atomdb               News                          3.0.8
# browse                                             v8.4
# browse_extract                                     1.0
# browse_extract_wget                                1.0
# camb                 Supports the                  April 2014
# casa                 search casa                   4.7.1
# ccfits               Last Modified:                2.5
# cfitsio              Last Modified:                3.410
# chianti              released,                     8.0
# ciao                 Last modified:                4.9
# cpl                  has been released             7.0
# ds9                                                7.5
# eclipse                                            5.0-0
# exsas                last update:                  01APR_EXP
# fv                   Last Modified:                5.4
# galprop              last modified:                August 12, 2016
# gasgano              last update:                  2.4
# grace                by the Grace Team             5.1.22
# gsl                  It was released on            2.3
# heasoft              RELEASE NOTES FOR HEASOFT     6.20
# idlaul               IDL Astronomy Users Library   08-Dec-2016
# iraf                 (Updated                      2.16
# iris                 Last Published                3.0b2
# isis                 Last updated                  1.6.2-35
# ...                           ...                       ...
# pyraf                The current version of PyRAF  2.1.14
# sae                  , released                    v10r0p5
# sas                  Release date:                 16.0.0
# scisoft              Last Update:                  8
# sextractor              sextractor                 2.3.1
# sherpa               was released on               4.9
# simx                 released                      2.4.1
# skyview              Posted On                     3.2.2
# specview                                           2.17.6
# spex                 available, in                 3.03.00
# splash               The current release is        2.6.0
# starlink
# starview             Last Update:                  0.1alpha
# stsci_python         It was released in            2.15.1
# stsdas               was released in               3.17
# synspec              Last update:                  43
# tara                 tara2                         2016sep26
# tempo2                                             2017.02.1
# tlusty               Last update:                  202
# visit                FAQs                          2.12.1
# vltpipe              Latest News:                  1.6.4
# wcslib               Generated on                  5.16
# webhera              The current release is
# window2stars         /                             0.39
# xamin                xmsetup.releaseDate           4.0.1335/3403
# ximage               Part of HEAsoft               4.5.1
# xronos               Last modified:                5.21
# xsa                                                9.2
# xspec                updated                       12.9.0
# xstar                xstar                         09
#
#                                                                                            download_url  \
# acis_extract         http://www.astro.psu.edu/xray/docs/TARA/code
# aips                 http://www.aips.nrao.edu/index.shtml#CURRENT_RELEASE
# aladin               http://aladin.u-strasbg.fr/AladinDesktop/#Download
# amuse                http://www.amusecode.org
# apt                  http://www.stsci.edu/hst/proposing/apt
# astrogrid            http://www.astrogrid.org/
# atomdb               http://atomdb.org
# browse               http://heasarc.gsfc.nasa.gov/W3Browse/
# browse_extract       http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract.pl
# browse_extract_wget  http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract_wget.pl
# camb                 http://lambda.gsfc.nasa.gov/toolbox/tb_camb_form.cfm
# casa                 https://casa.nrao.edu/casa_obtaining.shtml
# ccfits               http://heasarc.gsfc.nasa.gov/docs/software/fitsio/ccfits/
# cfitsio              http://heasarc.gsfc.nasa.gov/docs/software/fitsio/fitsio.html
# chianti              http://www.chianti.rl.ac.uk/
# ciao                 http://cxc.harvard.edu/ciao/download/
# cpl                  http://www.eso.org/sci/software/cpl/
# ds9                  http://ds9.si.edu/site/Download.html
# eclipse              http://www.eso.org/sci/software/eclipse/
# exsas                http://www.mpe.mpg.de/xray/wave/exsas/exsas_index.php
# fv                   http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/ftools/fv/
# galprop              http://galprop.stanford.edu/
# gasgano              http://www.eso.org/sci/software/gasgano/
# grace                http://plasma-gate.weizmann.ac.il/Grace/
# gsl                   ftp://ftp.gnu.org/gnu/gsl/
# heasoft              http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/download.html
# idlaul               http://idlastro.gsfc.nasa.gov/news.html
# iraf                 http://iraf.noao.edu/
# iris                 http://cxc.cfa.harvard.edu/iris/latest/download/index.html
# isis                 http://space.mit.edu/CXC/isis/download.html
# ...                                                          ...
# pyraf                http://www.stsci.edu/institute/software_hardware/pyraf/current/download
# sae                  http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/
# sas                  http://xmm.esac.esa.int/sas/current/download/
# scisoft              http://www.eso.org/sci/software/scisoft/
# sextractor           https://sourceforge.net/projects/sextractor/files/
# sherpa               http://cxc.harvard.edu/sherpa/updates.html
# simx                 http://hea-www.cfa.harvard.edu/simx/download.html
# skyview              http://skyview.gsfc.nasa.gov/current/cgi/titlepage.pl
# specview             http://www.stsci.edu/institute/software_hardware/specview/download
# spex                 https://www.sron.nl/astrophysics-spex/download/
# splash               http://users.monash.edu.au/~dprice/splash/index.html
# starlink             http://starlink.eao.hawaii.edu/starlink
# starview             http://starview.sourceforge.net/
# stsci_python         http://www.stsci.edu/institute/software_hardware/pyraf/stsci_python/installation
# stsdas               http://www.stsci.edu/resources/software_hardware/stsdas
# synspec              http://nova.astro.umd.edu/Synspec43/synspec.html
# tara                 http://www.astro.psu.edu/xray/docs/TARA/ae_users_guide.html
# tempo2               http://www.atnf.csiro.au/research/pulsar/tempo2/
# tlusty               http://nova.astro.umd.edu/index.html
# visit                https://wci.llnl.gov/simulation/computer-codes/visit/downloads
# vltpipe              http://www.eso.org/sci/software/pipelines/
# wcslib               http://www.atnf.csiro.au/people/mcalabre/WCS/wcslib/
# webhera              http://heasarc.gsfc.nasa.gov/webHera/
# window2stars         http://www.ast.cam.ac.uk/~rgi/window.html
# xamin                http://heasarc.gsfc.nasa.gov/xamin/
# ximage               http://heasarc.gsfc.nasa.gov/docs/xanadu/ximage/ximage.html
# xronos               http://heasarc.gsfc.nasa.gov/docs/xanadu/xronos/xronos.html
# xsa                  http://xmm.esac.esa.int/xsa
# xspec                http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/issues/issues.html
# xstar                http://heasarc.gsfc.nasa.gov/docs/software/xstar/xstar.html
#
#                                                                                             version_url  \
# acis_extract         http://www.astro.psu.edu/xray/docs/TARA/code
# aips                 http://www.aips.nrao.edu/cook.html
# aladin               http://aladin.u-strasbg.fr/java/nph-aladin.pl?frame=downloading#Beta
# amuse                http://www.amusecode.org
# apt                  http://www.stsci.edu/hst/proposing/apt
# astrogrid            http://www.astrogrid.org/
# atomdb               http://atomdb.org
# browse               http://heasarc.gsfc.nasa.gov/W3Browse/version-history.html
# browse_extract       http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract.pl
# browse_extract_wget  http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract_wget.pl
# camb                 http://lambda.gsfc.nasa.gov/toolbox/tb_camb_form.cfm
# casa                 https://casa.nrao.edu/casa_obtaining.shtml
# ccfits               http://heasarc.gsfc.nasa.gov/docs/software/fitsio/ccfits/
# cfitsio              http://heasarc.gsfc.nasa.gov/docs/software/fitsio/fitsio.html
# chianti              http://www.chianti.rl.ac.uk/
# ciao                 http://cxc.harvard.edu/ciao/download/
# cpl                  http://www.eso.org/sci/software/cpl/
# ds9                  http://ds9.si.edu/site/Home.html
# eclipse              http://www.eso.org/sci/software/eclipse/distrib/index.html
# exsas                http://www.mpe.mpg.de/xray/wave/exsas/exsas_index.php
# fv                   http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/ftools/fv/
# galprop              http://galprop.stanford.edu/
# gasgano              http://www.eso.org/sci/software/gasgano.html
# grace                http://plasma-gate.weizmann.ac.il/Grace/doc/UsersGuide.html
# gsl                  http://www.gnu.org/software/gsl/
# heasoft              http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/release_notes.html
# idlaul               http://idlastro.gsfc.nasa.gov/news.html
# iraf                 http://iraf.noao.edu/
# iris                 http://cxc.cfa.harvard.edu/iris/latest/releasenotes/index.html
# isis                 http://space.mit.edu/CXC/isis/download.html
# ...                                                          ...
# pyraf                http://www.stsci.edu/institute/software_hardware/pyraf/current/download
# sae                  http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/
# sas                  https://www.cosmos.esa.int/web/xmm-newton/sas-news
# scisoft              http://www.eso.org/sci/software/scisoft/
# sextractor           https://sourceforge.net/projects/sextractor/files/
# sherpa               http://cxc.harvard.edu/sherpa/updates.html
# simx                 http://hea-www.cfa.harvard.edu/simx/download.html
# skyview              http://skyview.gsfc.nasa.gov/blog/
# specview             http://www.stsci.edu/institute/software_hardware/specview/stvhistory
# spex                 https://www.sron.nl/astrophysics-spex/download/
# splash               http://users.monash.edu.au/~dprice/splash/index.html
# starlink             http://starlink.eao.hawaii.edu/starlink/Releases
# starview             https://sourceforge.net/projects/starview/
# stsci_python         http://www.stsci.edu/institute/software_hardware/pyraf/stsci_python
# stsdas               http://www.stsci.edu/resources/software_hardware/stsdas
# synspec              http://nova.astro.umd.edu/Synspec43/synspec-toc
# tara                 http://www2.astro.psu.edu/xray/docs/TARA/code/
# tempo2               https://bitbucket.org/psrsoft/tempo2/downloads
# tlusty               http://nova.astro.umd.edu/Tlusty2002/tlusty-toc.html
# visit                https://wci.llnl.gov/simulation/computer-codes/visit/new
# vltpipe              http://www.eso.org/sci/software/pipelines/
# wcslib               http://www.atnf.csiro.au/people/mcalabre/WCS/wcslib/
# webhera              http://heasarc.gsfc.nasa.gov/webHera/
# window2stars         http://www.ast.cam.ac.uk/~rgi/code/wtts/CHANGES.WTTS
# xamin                http://heasarc.gsfc.nasa.gov/xamin/
# ximage               http://heasarc.gsfc.nasa.gov/docs/xanadu/ximage/ximrelease.html
# xronos               http://heasarc.gsfc.nasa.gov/docs/xanadu/xronos/xronrelease.html
# xsa                  https://www.cosmos.esa.int/web/xmm-newton/xsa
# xspec                http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/issues/issues.html
# xstar                http://heasarc.gsfc.nasa.gov/FTP/software/plasma_codes/xstar/
#
#                                            pattern_marker  \
# acis_extract
# aips                 VERSION FOR
# aladin               Beta version v
# amuse                Current release:
# apt                  Release Information
# astrogrid            developement project from
# atomdb               News
# browse
# browse_extract       # Version
# browse_extract_wget  # Version
# ...
# grace                http://plasma-gate.weizmann.ac.il/Grace/
# gsl                  http://www.fsf.org/
# heasoft              http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/
# idlaul               http://idlastro.gsfc.nasa.gov/homepage.html
# iraf                 http://iraf.noao.edu/
# iris                 http://cxc.cfa.harvard.edu/iris/latest/index.html
# isis                 http://space.mit.edu/CXC/isis/
# ...                                             ...
# pyraf                http://www.stsci.edu/institute/software_hardware/pyraf/
# sae                  http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/
# sas                  http://xmm.esac.esa.int/sas/
# scisoft              http://www.eso.org/sci/software/scisoft/
# sextractor           mailto:rosalia@galassi.org
# sherpa               http://cxc.harvard.edu/sherpa/
# simx                 http://hea-www.cfa.harvard.edu/simx/index.html
# skyview              http://skyview.gsfc.nasa.gov/current/cgi/titlepage.pl
# specview             http://www.stsci.edu/institute/software_hardware/specview
# spex                 http://www.sron.nl/spex
# splash               http://users.monash.edu.au/~dprice/splash/index.html
# starlink             http://starlink.eao.hawaii.edu/starlink
# starview             http://starview.sourceforge.net/
# stsci_python         http://www.stsci.edu/resources/software_hardware/pyraf/stsci_python
# stsdas               http://www.stsci.edu/resources/software_hardware/stsdas
# synspec              http://nova.astro.umd.edu/Synspec43/synspec.html
# tara                 http://www2.astro.psu.edu/xray/
# tempo2               http://www.atnf.csiro.au/research/pulsar/tempo2/
# tlusty               http://nova.astro.umd.edu/index.html
# visit                http://visit.llnl.gov
# vltpipe              http://www.eso.org/sci/software/pipelines/
# wcslib               http://www.atnf.csiro.au/people/mcalabre/WCS/index.html
# webhera              http://heasarc.gsfc.nasa.gov/webHera/
# window2stars         http://www.ast.cam.ac.uk/~rgi/window.html
# xamin                http://heasarc.gsfc.nasa.gov/xamin/
# ximage               http://heasarc.gsfc.nasa.gov/docs/xanadu/ximage/ximage.html
# xronos               http://heasarc.gsfc.nasa.gov/docs/xanadu/xronos/xronos.html
# xsa                  https://www.cosmos.esa.int/web/xmm-newton/xsa
# xspec                http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/
# xstar                http://heasarc.gsfc.nasa.gov/docs/software/xstar/xstar.html
#
#                     ad_release_date  \
# acis_extract         09/22/16
# aips                 12/31/16
# aladin               01/17/17
# amuse                09/17/14
# apt                  01/26/17
# astrogrid            08/15/12
# atomdb               12/08/16
# browse               10/09/07
# browse_extract       10/10/96
# browse_extract_wget  10/10/96
# camb                 04/16/14
# casa                 02/08/17
# ccfits               01/19/16
# cfitsio              12/02/16
# chianti              09/16/15
# ciao                 01/05/17
# cpl                  02/26/16
# ds9                  12/15/16
# eclipse              09/23/05
# exsas                12/10/03
# fv                   09/15/15
# galprop              08/12/16
# gasgano              10/22/15
# grace                05/20/08
# gsl                  12/09/16
# heasoft              01/18/17
# idlaul               12/08/16
# iraf                 03/22/12
# iris                 01/04/17
# isis                 09/12/16
# ...                       ...
# pyraf                01/16/17
# sae                  06/24/15
# sas                  01/16/17
# scisoft              06/28/16
# sextractor           04/09/02
# sherpa               12/16/16
# simx                 03/28/16
# skyview              12/13/16
# specview             06/02/14
# spex                 01/16/16
# splash               10/22/15
# starlink
# starview             03/07/13
# stsci_python         04/16/14
# stsdas               03/16/14
# synspec              10/05/05
# tara                 09/26/16
# tempo2               02/14/17
# tlusty               07/02/12
# visit                01/16/17
# vltpipe              01/27/17
# wcslib               01/15/17
# webhera
# window2stars         04/16/15
# xamin                02/14/17
# ximage               03/16/10
# xronos               05/07/04
# xsa                  11/30/16
# xspec                01/17/17
# xstar                01/10/17
#
#                                                                                                home_url  \
# acis_extract         http://www2.astro.psu.edu/xray/docs/TARA/ae_users_guide.html
# aips                 http://www.aips.nrao.edu/index.shtml
# aladin               http://aladin.u-strasbg.fr/AladinDesktop/
# amuse                http://www.amusecode.org
# apt                  http://www.stsci.edu/hst/proposing/apt
# astrogrid            http://www.astrogrid.org/
# atomdb               http://atomdb.org
# browse               http://heasarc.gsfc.nasa.gov/W3Browse/
# browse_extract       http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract.pl
# browse_extract_wget  http://heasarc.gsfc.nasa.gov/FTP/heasarc/software/web_batch/browse_extract_wget.pl
# camb                 http://lambda.gsfc.nasa.gov/toolbox/tb_camb_form.cfm
# casa                 https://casa.nrao.edu/
# ccfits               http://heasarc.gsfc.nasa.gov/docs/software/fitsio/ccfits/
# cfitsio              http://heasarc.gsfc.nasa.gov/docs/software/fitsio/fitsio.html
# chianti              http://www.chianti.rl.ac.uk/
# ciao                 http://cxc.harvard.edu/ciao/download/
# cpl                  http://www.eso.org/sci/software/cpl/
# ds9                  http://ds9.si.edu
# eclipse              http://www.eso.org/sci/software/eclipse/
# exsas                http://www.mpe.mpg.de/xray/wave/exsas/exsas_index.php
# fv                   http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/ftools/fv/
# galprop              http://galprop.stanford.edu/
# gasgano              http://www.eso.org/sci/software/gasgano/
# grace                http://plasma-gate.weizmann.ac.il/Grace/
# gsl                  http://www.gnu.org/software/gsl/
# heasoft              http://heasarc.gsfc.nasa.gov/docs/software/lheasoft/
# idlaul               http://idlastro.gsfc.nasa.gov/homepage.html
# iraf                 http://iraf.noao.edu/
# iris                 http://cxc.cfa.harvard.edu/iris/latest/index.html
# isis                 http://space.mit.edu/CXC/isis/
# ...                                             ...
# pyraf                http://www.stsci.edu/institute/software_hardware/pyraf/
# sae                  http://fermi.gsfc.nasa.gov/ssc/data/analysis/software/
# sas                  http://xmm.esac.esa.int/sas/
# scisoft              http://www.eso.org/sci/software/scisoft/
# sextractor           http://sextractor.sourceforge.net
# sherpa               http://cxc.harvard.edu/sherpa/
# simx                 http://hea-www.cfa.harvard.edu/simx/index.html
# skyview              http://skyview.gsfc.nasa.gov/current/cgi/titlepage.pl
# specview             http://www.stsci.edu/institute/software_hardware/specview
# spex                 http://www.sron.nl/spex
# splash               http://users.monash.edu.au/~dprice/splash/index.html
# starlink             http://starlink.eao.hawaii.edu/starlink
# starview             http://starview.sourceforge.net/
# stsci_python         http://www.stsci.edu/resources/software_hardware/pyraf/stsci_python
# stsdas               http://www.stsci.edu/resources/software_hardware/stsdas
# synspec              http://nova.astro.umd.edu/Synspec43/synspec.html
# tara                 http://www2.astro.psu.edu/xray/docs/TARA/code/
# tempo2               http://www.atnf.csiro.au/research/pulsar/tempo2/
# tlusty               http://nova.astro.umd.edu/index.html
# visit                http://visit.llnl.gov
# vltpipe              http://www.eso.org/sci/software/pipelines/
# wcslib               http://www.atnf.csiro.au/people/mcalabre/WCS/index.html
# webhera              http://heasarc.gsfc.nasa.gov/webHera/
# window2stars         http://www.ast.cam.ac.uk/~rgi/window.html
# xamin                http://heasarc.gsfc.nasa.gov/xamin/
# ximage               http://heasarc.gsfc.nasa.gov/docs/xanadu/ximage/ximage.html
# xronos               http://heasarc.gsfc.nasa.gov/docs/xanadu/xronos/xronos.html
# xsa                  http://xmm.esac.esa.int/xsa
# xspec                http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/
# xstar                http://heasarc.gsfc.nasa.gov/docs/software/xstar/xstar.html
#
#                                        name
# acis_extract         ACIS Extract
# aips                 AIPS
# aladin               Aladin
# amuse                AMUSE
# apt                  APT
# astrogrid            AstroGrid
# atomdb               ATOMDB
# browse               Browse
# browse_extract       browse_extract
# browse_extract_wget  browse_extract_wget
# camb                 CAMB
# casa                 CASA
# ccfits               CCFITS
# cfitsio              CFITSIO
# chianti              Chianti
# ciao                 CIAO
# cpl                  CPL
# ds9                  SAOImage/DS9
# eclipse              Eclipse
# exsas                EXSAS
# fv                   FV
# galprop              GALPROP
# gasgano              GASGANO
# grace                GRACE
# gsl                  Gnu Scientific Library
# heasoft              HEASoft
# idlaul               IDL AUL
# iraf                 IRAF
# iris                 IRIS
# isis                 ISIS
# ...                   ...
# pyraf                PYRAF
# sae                  SAE
# sas                  SAS
# scisoft              SciSoft
# sextractor           SEXtractor
# sherpa               Sherpa
# simx                 SIMX
# skyview              SkyView
# specview             Specview
# spex                 SPEX
# splash               SPLASH
# starlink             Starlink
# starview             Starview
# stsci_python         STSCI Python
# stsdas               STSDAS
# synspec              Synspec
# tara                 TARA
# tempo2               TEMPO2
# tlusty               TLUSTY
# visit                VISIT
# vltpipe              VLT Pipelines
# wcslib               WCS Lib
# webhera              Web Hera
# window2stars         Window to the Stars
# xamin                XAMIN
# ximage               XIMAGE
# xronos               XRONOS
# xsa                  XSA
# xspec                XSPEC
# xstar                XSTAR
#
# [69 rows x 16 columns]
